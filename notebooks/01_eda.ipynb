# %% [markdown]
# # SPEDIA EDA
#
# Start here. Load the raw CSV, check class balance, check ATT&CK stage distribution, check for label leakage before anyone builds an engine.

# %%
import pandas as pd

df = pd.read_csv('../data/raw/logs_SPEDIA.csv')
df.shape
